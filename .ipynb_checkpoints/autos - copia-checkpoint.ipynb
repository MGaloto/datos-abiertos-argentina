# %%
import pandas as pd
import numpy as np
import plotly.io as pio
import plotly.express as px
import plotly.figure_factory as ff
import matplotlib.pyplot as plt
from plotly.subplots import make_subplots
import matplotlib.patches
import matplotlib as mpl
import seaborn as sns
# %matplotlib inline
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics
from math import sqrt
from io import BytesIO
from zipfile import ZipFile
from urllib.request import urlopen
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.arima_model import ARMA
from scipy.stats.distributions import chi2
import statsmodels.tsa.stattools as sts
from statsmodels.tsa.seasonal import seasonal_decompose
import seaborn as sns
import pmdarima as pm
from os import listdir
import warnings

warnings.filterwarnings('ignore')

# %%
def plot_hbar(df, x, y, title):
    fig = px.bar(df, 
                 x=x, y=y, 
                 text=x, orientation='v', width=700, color = x)
    fig.update_layout(title=title, xaxis_title=x, yaxis_title=y,
                      uniformtext_minsize=8, uniformtext_mode='hide')
    fig.show()

# %%
dfs = pd.read_csv('df.csv').drop(columns = 'Unnamed: 0')

# %%
dfs.head(5)
# Out:
#   tramite_fecha registro_seccional_provincia  count
# 0    2018-09-14                      Córdoba    858
# 1    2018-09-28                   Entre Ríos    268
# 2    2018-09-07                      Mendoza    423
# 3    2018-09-04                    Río Negro    152
# 4    2018-09-20                    Catamarca     43

# %%
df = dfs.pivot_table(index='tramite_fecha',
               columns='registro_seccional_provincia',
               values='count',
               fill_value=0)

df.columns.name = None              

df = df.loc[:,~df.apply(lambda x: x.duplicated(),axis=1).all()].copy()

# %%
df["sum"] = df[df.columns[1:]].sum(axis=1)

# %%
df["sum"].describe()
# Out:
# count    1315.000000
# mean     3536.034981
# std      1757.163498
# min         0.000000
# 25%      3727.000000
# 50%      4277.000000
# 75%      4605.500000
# max      5633.000000
# Name: sum, dtype: float64

# %%
from pandas.tseries.offsets import BDay
isBusinessDay = BDay().onOffset

df['tramite_fecha'] = df.index
df["tramite_fecha"] = pd.to_datetime(df["tramite_fecha"])

match_series = pd.to_datetime(df['tramite_fecha']).map(isBusinessDay)
#df = df[(df['Ciudad Autónoma de Bs.As.']>= 1) & (df['Córdoba']>= 1)]
df = df[(df['sum'] >= 100)]
df = df[match_series]

df_copy = df.copy()

# %%
def get_time_series(values):
    plt.rcParams["figure.figsize"] = (16,6)
    fig, ax1 = plt.subplots()
    for value in values:
        ax1.plot(df_copy['tramite_fecha'], df_copy[value], label=value);
    ax1.legend(values)
    plt.title('Transferencias de autos\nTrámites de transferencia de automotores inscriptos en los Registros Seccionales de la Propiedad del Automotor y Créditos Prendarios.')
    return plt.show()

get_time_series(['Ciudad Autónoma de Bs.As.', 'Córdoba'])

# %%
df['año']     = pd.DatetimeIndex(df['tramite_fecha']).year
df['mes_año'] = pd.to_datetime(df['tramite_fecha']).dt.to_period('M')

# %%
def get_line_plot(dataframe, x, y1, y2, titulo, rolling = False, periods = False):
    df = dataframe.copy()
    if rolling == True:
        df[y1] = df[y1].rolling(window=periods).mean()
        df[y2] = df[y2].rolling(window=periods).mean()
    subfig = make_subplots(specs=[[{"secondary_y": True}]])
    fig  = px.line(df, x=x, y=y1)
    fig2 = px.line(df, x=x,y=y2)
    fig.update_layout(xaxis_rangeslider_visible=True)
    fig.update_traces(showlegend=True,name=y1,line_color='red', line_width=1)
    fig2.update_traces(showlegend=True,name=y2,line_color='#0000ff', line_width=1, yaxis="y2")
    subfig.add_traces(fig.data + fig2.data)
    subfig.layout.xaxis.title ="Periodos"
    subfig.layout.yaxis.title =y1
    subfig.layout.yaxis2.title=y2
    subfig.layout.title=titulo 
    return subfig.show()

# %%
get_line_plot(df_copy, "tramite_fecha", "Salta", "Tierra del Fuego", "Transacciones Autos Usados Argentina 2018 - 2022")

# %%
columnas = []
values   = []

for i in range(len(df_copy.drop(columns = ['sum','tramite_fecha']).columns)):
    try:
        columnas.append(df_copy.drop(columns =['sum','tramite_fecha']).columns[i])
        values.append(df_copy[df_copy.drop(columns = ['sum','tramite_fecha']).columns[i]].sum())
    except:
        continue

df_group = pd.DataFrame({'indice': columnas, 'n' : values}).sort_values(by = 'n', ascending = False)

# %%
plot_hbar(df_group, 'indice', 'n',  'Transacciones')

# %%
df_mes = df.groupby('mes_año')[df.columns.drop(["tramite_fecha", 'año', 'mes_año'])].mean().reset_index()
df_mes["mes_año"] = [d.to_timestamp() for d in df_mes["mes_año"].values]

# %%
get_line_plot(df_mes, "mes_año", "Ciudad Autónoma de Bs.As.", "Córdoba", "Transacciones Autos Usados Argentina 2018 - 2022 Datos Mensuales")

# %%
df_mes["mes_año"] = pd.to_datetime(df_mes["mes_año"])
df_mes['año'] = pd.to_datetime(df_mes["mes_año"]).dt.year
#df_mes.to_csv(r'cars.csv')

# %% [markdown]
# # Inicio del Modelo

# %% [markdown]
# Desde el 18 de marzo al 19 de junio no contamos con datos. Si bien no es buena practica en series de tiempo alterar los datos en este caso, la pandemia ha alterado todas las series temporales. Para este caso se va a tener en cuenta los promedios de los otros años para esas fechas asi podemos completar al serie temporal.

# %%
[df_copy.columns]
# Out:
# [Index(['Buenos Aires', 'Catamarca', 'Chaco', 'Chubut',
#         'Ciudad Autónoma de Bs.As.', 'Corrientes', 'Córdoba', 'Entre Ríos',
#         'Formosa', 'Jujuy', 'La Pampa', 'La Rioja', 'Mendoza', 'Misiones',
#         'Neuquén', 'Río Negro', 'Salta', 'San Juan', 'San Luis', 'Santa Cruz',
#         'Santa Fe', 'Santiago del Estero', 'Tierra del Fuego', 'Tucumán', 'sum',
#         'tramite_fecha'],
#        dtype='object')]

# %%
def get_dataframe(values, desde, hasta, years):
    data_frames = []
    for year in years:
        df_append = df_copy.loc[(df_copy['tramite_fecha'].dt.strftime('%m-%d') >= desde) & (df_copy['tramite_fecha'].dt.strftime('%m-%d') <= hasta) & (df_copy['tramite_fecha'].dt.strftime('%Y') == year)][values]
        data_frames.append(df_append)
    df_final_concat = pd.concat(data_frames, ignore_index=True)
    df_final_concat['month_day'] = df_final_concat['tramite_fecha'].dt.strftime('%m-%d')
    df_values = df_final_concat.groupby('month_day' ,as_index = False).mean().round(0)
    return df_values

start    = '03-18'
end      = '06-19'
columnas = ['tramite_fecha', 'Buenos Aires', 'Catamarca', 'Chaco', 'Chubut','Ciudad Autónoma de Bs.As.', 'Corrientes', 'Córdoba', 'Entre Ríos',
        'Formosa', 'Jujuy', 'La Pampa', 'La Rioja', 'Mendoza', 'Misiones',
        'Neuquén', 'Río Negro', 'Salta', 'San Juan', 'San Luis', 'Santa Cruz', 'Santa Fe', 'Santiago del Estero', 'Tierra del Fuego', 'Tucumán', 'sum']

df_values = get_dataframe(columnas, start, end, ['2018', '2019', '2021', '2022'])

# %%
df_values['month_day'] = df_values.apply(lambda x: '2020-' + str(x['month_day']), axis = 1)

df_values['month_day'] = pd.to_datetime(df_values['month_day'], format='%Y-%m-%d')

df_values.head(5)
# Out:
#    month_day  Buenos Aires  Catamarca  Chaco  Chubut  \
# 0 2020-03-18        2622.0       28.0   80.0   123.0
# 1 2020-03-19        2629.0       29.0  108.0   149.0
# 2 2020-03-20        2530.0       38.0  114.0   132.0
# 3 2020-03-21        2588.0       27.0   96.0   121.0
# 4 2020-03-22        2768.0       30.0   99.0   146.0
#
#    Ciudad Autónoma de Bs.As.  Corrientes  Córdoba  Entre Ríos  Formosa  ...  \
# 0                      654.0       106.0    817.0       282.0     30.0  ...
# 1                      666.0       108.0    770.0       252.0     29.0  ...
# 2                      670.0       124.0    771.0       291.0     30.0  ...
# 3                      704.0       109.0    821.0       297.0     42.0  ...
# 4                      706.0       110.0    856.0       292.0     38.0  ...
#
#    Río Negro  Salta  San Juan  San Luis  Santa Cruz  Santa Fe  \
# 0      150.0   70.0      93.0      74.0        56.0     619.0
# 1      138.0   82.0      89.0     103.0        62.0     603.0
# 2      163.0   94.0      90.0      92.0        63.0     646.0
# 3      160.0   86.0      91.0     101.0        61.0     638.0
# 4      154.0   82.0      92.0     100.0        64.0     656.0
#
#    Santiago del Estero  Tierra del Fuego  Tucumán     sum
# 0                 48.0              43.0    119.0  4152.0
# 1                 59.0              41.0    120.0  4183.0
# 2                 40.0              56.0    110.0  4374.0
# 3                 48.0              36.0    122.0  4371.0
# 4                 51.0              45.0    128.0  4467.0
#
# [5 rows x 26 columns]

# %%
df_values.rename(columns = {'month_day':'tramite_fecha'}, inplace = True)

# %%
df_values.index = df_values.tramite_fecha
df_values.head(3)
# Out:
#               tramite_fecha  Buenos Aires  Catamarca  Chaco  Chubut  \
# tramite_fecha
# 2020-03-18       2020-03-18        2622.0       28.0   80.0   123.0
# 2020-03-19       2020-03-19        2629.0       29.0  108.0   149.0
# 2020-03-20       2020-03-20        2530.0       38.0  114.0   132.0
#
#                Ciudad Autónoma de Bs.As.  Corrientes  Córdoba  Entre Ríos  \
# tramite_fecha
# 2020-03-18                         654.0       106.0    817.0       282.0
# 2020-03-19                         666.0       108.0    770.0       252.0
# 2020-03-20                         670.0       124.0    771.0       291.0
#
#                Formosa  ...  Río Negro  Salta  San Juan  San Luis  Santa Cruz  \
# tramite_fecha           ...
# 2020-03-18        30.0  ...      150.0   70.0      93.0      74.0        56.0
# 2020-03-19        29.0  ...      138.0   82.0      89.0     103.0        62.0
# 2020-03-20        30.0  ...      163.0   94.0      90.0      92.0        63.0
#
#                Santa Fe  Santiago del Estero  Tierra del Fuego  Tucumán  \
# tramite_fecha
# 2020-03-18        619.0                 48.0              43.0    119.0
# 2020-03-19        603.0                 59.0              41.0    120.0
# 2020-03-20        646.0                 40.0              56.0    110.0
#
#                   sum
# tramite_fecha
# 2020-03-18     4152.0
# 2020-03-19     4183.0
# 2020-03-20     4374.0
#
# [3 rows x 26 columns]

# %%
df_ts_1 = df_copy[columnas]

df_ts_1.head(3)
# Out:
#               tramite_fecha  Buenos Aires  Catamarca  Chaco  Chubut  \
# tramite_fecha
# 2018-01-02       2018-01-02          2719         43     94     145
# 2018-01-03       2018-01-03          2809         45    141     134
# 2018-01-04       2018-01-04          2857         30    121     139
#
#                Ciudad Autónoma de Bs.As.  Corrientes  Córdoba  Entre Ríos  \
# tramite_fecha
# 2018-01-02                           594         178      877         271
# 2018-01-03                           672         184      737         285
# 2018-01-04                           714         157      760         286
#
#                Formosa  ...  Río Negro  Salta  San Juan  San Luis  Santa Cruz  \
# tramite_fecha           ...
# 2018-01-02          44  ...        182    130        89       106          70
# 2018-01-03          42  ...        182     69        95       112          49
# 2018-01-04          43  ...        169    118       108       110          81
#
#                Santa Fe  Santiago del Estero  Tierra del Fuego  Tucumán   sum
# tramite_fecha
# 2018-01-02          724                   74                39      157  4666
# 2018-01-03          623                   51                41      167  4577
# 2018-01-04          689                   68                50      182  4773
#
# [3 rows x 26 columns]

# %%
df_ts_1.index =  pd.to_datetime(df_ts_1.index, format='%Y-%m-%d')

# %%
df_ts_1['tramite_fecha']   = df_ts_1.index
df_values['tramite_fecha'] = df_values.index

# %%
delete_index = list(df_values.index.unique())

# %%
df_ts = pd.concat([df_ts_1[~df_ts_1.index.isin(delete_index)], df_values], ignore_index = False)

# %%
df_ts.head(3)
# Out:
#               tramite_fecha  Buenos Aires  Catamarca  Chaco  Chubut  \
# tramite_fecha
# 2018-01-02       2018-01-02        2719.0       43.0   94.0   145.0
# 2018-01-03       2018-01-03        2809.0       45.0  141.0   134.0
# 2018-01-04       2018-01-04        2857.0       30.0  121.0   139.0
# 2018-01-05       2018-01-05        2884.0       46.0  122.0   162.0
# 2018-01-08       2018-01-08        2711.0       35.0  130.0   165.0
# ...                     ...           ...        ...    ...     ...
# 2020-06-15       2020-06-15        2647.0       22.0  102.0   124.0
# 2020-06-16       2020-06-16        2666.0       25.0   96.0   124.0
# 2020-06-17       2020-06-17        2502.0       17.0   90.0   132.0
# 2020-06-18       2020-06-18        2522.0       21.0   82.0   130.0
# 2020-06-19       2020-06-19        2528.0       32.0  106.0   144.0
#
#                Ciudad Autónoma de Bs.As.  Corrientes  Córdoba  Entre Ríos  \
# tramite_fecha
# 2018-01-02                         594.0       178.0    877.0       271.0
# 2018-01-03                         672.0       184.0    737.0       285.0
# 2018-01-04                         714.0       157.0    760.0       286.0
# 2018-01-05                         757.0       179.0    838.0       300.0
# 2018-01-08                         699.0       162.0    803.0       293.0
# ...                                  ...         ...      ...         ...
# 2020-06-15                         667.0       110.0    780.0       282.0
# 2020-06-16                         646.0       120.0    790.0       280.0
# 2020-06-17                         592.0        98.0    737.0       241.0
# 2020-06-18                         628.0        97.0    814.0       279.0
# 2020-06-19                         678.0       120.0    834.0       288.0
#
#                Formosa  ...  Río Negro  Salta  San Juan  San Luis  Santa Cruz  \
# tramite_fecha           ...
# 2018-01-02        44.0  ...      182.0  130.0      89.0     106.0        70.0
# 2018-01-03        42.0  ...      182.0   69.0      95.0     112.0        49.0
# 2018-01-04        43.0  ...      169.0  118.0     108.0     110.0        81.0
# 2018-01-05        56.0  ...      171.0  103.0     121.0     116.0        72.0
# 2018-01-08        47.0  ...      188.0  142.0      96.0      71.0        62.0
# ...                ...  ...        ...    ...       ...       ...         ...
# 2020-06-15        22.0  ...      141.0   68.0      85.0      93.0        46.0
# 2020-06-16        29.0  ...      144.0   87.0      76.0      98.0        66.0
# 2020-06-17        19.0  ...      145.0    0.0      85.0      86.0        48.0
# 2020-06-18        32.0  ...      148.0   70.0      97.0      97.0        45.0
# 2020-06-19        38.0  ...      161.0   80.0     110.0     108.0        60.0
#
#                Santa Fe  Santiago del Estero  Tierra del Fuego  Tucumán  \
# tramite_fecha
# 2018-01-02        724.0                 74.0              39.0    157.0
# 2018-01-03        623.0                 51.0              41.0    167.0
# 2018-01-04        689.0                 68.0              50.0    182.0
# 2018-01-05        643.0                 71.0              55.0    149.0
# 2018-01-08        641.0                 85.0              39.0    137.0
# ...                 ...                  ...               ...      ...
# 2020-06-15        674.0                 41.0              41.0    121.0
# 2020-06-16        694.0                 52.0              36.0    118.0
# 2020-06-17        654.0                 37.0              41.0    107.0
# 2020-06-18        665.0                 59.0              39.0    117.0
# 2020-06-19        702.0                 60.0              38.0    141.0
#
#                   sum
# tramite_fecha
# 2018-01-02     4666.0
# 2018-01-03     4577.0
# 2018-01-04     4773.0
# 2018-01-05     4912.0
# 2018-01-08     4682.0
# ...               ...
# 2020-06-15     4218.0
# 2020-06-16     4265.0
# 2020-06-17     3868.0
# 2020-06-18     4251.0
# 2020-06-19     4618.0
#
# [1117 rows x 26 columns]

# %%
df_ts.index.name = 'index'
df_ts.sort_values(by = 'tramite_fecha', inplace = True)

# %%
df_ts.head(5)
# Out:
#            tramite_fecha  Buenos Aires  Catamarca  Chaco  Chubut  \
# index
# 2018-01-02    2018-01-02        2719.0       43.0   94.0   145.0
# 2018-01-03    2018-01-03        2809.0       45.0  141.0   134.0
# 2018-01-04    2018-01-04        2857.0       30.0  121.0   139.0
# 2018-01-05    2018-01-05        2884.0       46.0  122.0   162.0
# 2018-01-08    2018-01-08        2711.0       35.0  130.0   165.0
#
#             Ciudad Autónoma de Bs.As.  Corrientes  Córdoba  Entre Ríos  \
# index
# 2018-01-02                      594.0       178.0    877.0       271.0
# 2018-01-03                      672.0       184.0    737.0       285.0
# 2018-01-04                      714.0       157.0    760.0       286.0
# 2018-01-05                      757.0       179.0    838.0       300.0
# 2018-01-08                      699.0       162.0    803.0       293.0
#
#             Formosa  ...  Río Negro  Salta  San Juan  San Luis  Santa Cruz  \
# index                ...
# 2018-01-02     44.0  ...      182.0  130.0      89.0     106.0        70.0
# 2018-01-03     42.0  ...      182.0   69.0      95.0     112.0        49.0
# 2018-01-04     43.0  ...      169.0  118.0     108.0     110.0        81.0
# 2018-01-05     56.0  ...      171.0  103.0     121.0     116.0        72.0
# 2018-01-08     47.0  ...      188.0  142.0      96.0      71.0        62.0
#
#             Santa Fe  Santiago del Estero  Tierra del Fuego  Tucumán     sum
# index
# 2018-01-02     724.0                 74.0              39.0    157.0  4666.0
# 2018-01-03     623.0                 51.0              41.0    167.0  4577.0
# 2018-01-04     689.0                 68.0              50.0    182.0  4773.0
# 2018-01-05     643.0                 71.0              55.0    149.0  4912.0
# 2018-01-08     641.0                 85.0              39.0    137.0  4682.0
#
# [5 rows x 26 columns]

# %%
get_line_plot(df_ts, "tramite_fecha", "sum", "Corrientes", "Transacciones Autos Usados Argentina 2018 - 2022 Datos Diarios")

# %%
df_ts['mes_año'] = pd.to_datetime(df_ts['tramite_fecha']).dt.to_period('M')

df_mes = df_ts.groupby('mes_año')[df_ts.columns.drop(["tramite_fecha"])].mean().round(0).reset_index()

# %%
df_mes["mes_año"] = [d.to_timestamp() for d in df_mes["mes_año"].values]

# %%
get_line_plot(df_mes, "mes_año", "sum", "Corrientes", "Transacciones Autos Usados Argentina 2018 - 2022 Datos Mensuales")

# %%
df_ts.head(5)
# Out:
#            tramite_fecha  Buenos Aires  Catamarca  Chaco  Chubut  \
# index
# 2018-01-02    2018-01-02        2719.0       43.0   94.0   145.0
# 2018-01-03    2018-01-03        2809.0       45.0  141.0   134.0
# 2018-01-04    2018-01-04        2857.0       30.0  121.0   139.0
# 2018-01-05    2018-01-05        2884.0       46.0  122.0   162.0
# 2018-01-08    2018-01-08        2711.0       35.0  130.0   165.0
#
#             Ciudad Autónoma de Bs.As.  Corrientes  Córdoba  Entre Ríos  \
# index
# 2018-01-02                      594.0       178.0    877.0       271.0
# 2018-01-03                      672.0       184.0    737.0       285.0
# 2018-01-04                      714.0       157.0    760.0       286.0
# 2018-01-05                      757.0       179.0    838.0       300.0
# 2018-01-08                      699.0       162.0    803.0       293.0
#
#             Formosa  ...  Salta  San Juan  San Luis  Santa Cruz  Santa Fe  \
# index                ...
# 2018-01-02     44.0  ...  130.0      89.0     106.0        70.0     724.0
# 2018-01-03     42.0  ...   69.0      95.0     112.0        49.0     623.0
# 2018-01-04     43.0  ...  118.0     108.0     110.0        81.0     689.0
# 2018-01-05     56.0  ...  103.0     121.0     116.0        72.0     643.0
# 2018-01-08     47.0  ...  142.0      96.0      71.0        62.0     641.0
#
#             Santiago del Estero  Tierra del Fuego  Tucumán     sum  mes_año
# index
# 2018-01-02                 74.0              39.0    157.0  4666.0  2018-01
# 2018-01-03                 51.0              41.0    167.0  4577.0  2018-01
# 2018-01-04                 68.0              50.0    182.0  4773.0  2018-01
# 2018-01-05                 71.0              55.0    149.0  4912.0  2018-01
# 2018-01-08                 85.0              39.0    137.0  4682.0  2018-01
#
# [5 rows x 27 columns]

# %%
df_ts.head(5)
# Out:
#            tramite_fecha  Buenos Aires  Catamarca  Chaco  Chubut  \
# index
# 2018-01-02    2018-01-02        2719.0       43.0   94.0   145.0
# 2018-01-03    2018-01-03        2809.0       45.0  141.0   134.0
# 2018-01-04    2018-01-04        2857.0       30.0  121.0   139.0
# 2018-01-05    2018-01-05        2884.0       46.0  122.0   162.0
# 2018-01-08    2018-01-08        2711.0       35.0  130.0   165.0
#
#             Ciudad Autónoma de Bs.As.  Corrientes  Córdoba  Entre Ríos  \
# index
# 2018-01-02                      594.0       178.0    877.0       271.0
# 2018-01-03                      672.0       184.0    737.0       285.0
# 2018-01-04                      714.0       157.0    760.0       286.0
# 2018-01-05                      757.0       179.0    838.0       300.0
# 2018-01-08                      699.0       162.0    803.0       293.0
#
#             Formosa  ...  Salta  San Juan  San Luis  Santa Cruz  Santa Fe  \
# index                ...
# 2018-01-02     44.0  ...  130.0      89.0     106.0        70.0     724.0
# 2018-01-03     42.0  ...   69.0      95.0     112.0        49.0     623.0
# 2018-01-04     43.0  ...  118.0     108.0     110.0        81.0     689.0
# 2018-01-05     56.0  ...  103.0     121.0     116.0        72.0     643.0
# 2018-01-08     47.0  ...  142.0      96.0      71.0        62.0     641.0
#
#             Santiago del Estero  Tierra del Fuego  Tucumán     sum  mes_año
# index
# 2018-01-02                 74.0              39.0    157.0  4666.0  2018-01
# 2018-01-03                 51.0              41.0    167.0  4577.0  2018-01
# 2018-01-04                 68.0              50.0    182.0  4773.0  2018-01
# 2018-01-05                 71.0              55.0    149.0  4912.0  2018-01
# 2018-01-08                 85.0              39.0    137.0  4682.0  2018-01
#
# [5 rows x 27 columns]

# %% [markdown]
# Prueba de Dickey Fuller para verificar si un conjunto de datos proviene de un proceso estacionario o no. La prueba esta basada en un contraste de hipotesis.
#
# Hipotesis Nula: La serie no es estacionaria
#
# Hipotesis Alternativa: La serie es estacionaria

# %%
def get_adfuller(value):
    if sts.adfuller(value)[0] > sts.adfuller(value)[4]['1%']:
        print('No rechazamos hipotesis nula, la serie NO ES estacionaria a un nivel de significacion del 1 % con un numero de retrasos de: ', sts.adfuller(value)[2])
    elif sts.adfuller(value)[0] > sts.adfuller(value)[4]['5%']:
        print('No rechazamos hipotesis nula, la serie NO ES estacionaria a un nivel de significacion del 5 % con un numero de retrasos de: ', sts.adfuller(value)[2])
    elif sts.adfuller(value)[0] > sts.adfuller(value)[4]['10%']:
        print('No rechazamos hipotesis nula, la serie NO ES estacionaria a un nivel de significacion del 10 % con un numero de retrasos de: ', sts.adfuller(value)[2])

    else: print('La serie ES estacionaria')
    return sts.adfuller(value)

get_adfuller(df_ts["Córdoba"])
# Out:
# La serie ES estacionaria
# (-4.198211572879862,
#  0.0006635083093469407,
#  9,
#  1107,
#  {'1%': -3.436270983129607,
#   '5%': -2.8641544150183553,
#   '10%': -2.5681619941180744},
#  12169.971413272051)

# %% [markdown]
# Estacionalidad:
#
# Sugiere que ciertas tendencias aparecerán de forma cíclica, por ejemplo, las temperaturas suben y bajan a lo largo del tiempo. La series se pueden descomponer bajo efecto tendencia donde podemos quitar un patrón sostenido en los datos, la estacional los efectos cíclicos y el residual el error entre los datos reales y el modelo que estamos ejecutando.
#
# La descomposición clásica puede ser aditiva o multiplicativa, en la aditiva podemos suponer que en cualquier momento del tiempo el valor observado es la suma de la tendencia, el objeto estacional y el efecto residual para ese periodo.
#
# La descomposición multiplicativa nos dice que la serie original es un producto de los tres efectos anteriories.

# %%
df_ts.sort_index(inplace=True)

# %%
df_ts.dropna(axis = 0, inplace=True)

# %%
df_ts.index
# Out:
# DatetimeIndex(['2018-01-02', '2018-01-03', '2018-01-04', '2018-01-05',
#                '2018-01-08', '2018-01-09', '2018-01-10', '2018-01-11',
#                '2018-01-12', '2018-01-15',
#                ...
#                '2022-06-14', '2022-06-15', '2022-06-16', '2022-06-21',
#                '2022-06-22', '2022-06-23', '2022-06-24', '2022-06-28',
#                '2022-06-29', '2022-06-30'],
#               dtype='datetime64[ns]', name='index', length=1117, freq=None)

# %%
df_ts.head(3)
# Out:
#            tramite_fecha  Buenos Aires  Catamarca  Chaco  Chubut  \
# index
# 2018-01-02    2018-01-02        2719.0       43.0   94.0   145.0
# 2018-01-03    2018-01-03        2809.0       45.0  141.0   134.0
# 2018-01-04    2018-01-04        2857.0       30.0  121.0   139.0
#
#             Ciudad Autónoma de Bs.As.  Corrientes  Córdoba  Entre Ríos  \
# index
# 2018-01-02                      594.0       178.0    877.0       271.0
# 2018-01-03                      672.0       184.0    737.0       285.0
# 2018-01-04                      714.0       157.0    760.0       286.0
#
#             Formosa  ...  Salta  San Juan  San Luis  Santa Cruz  Santa Fe  \
# index                ...
# 2018-01-02     44.0  ...  130.0      89.0     106.0        70.0     724.0
# 2018-01-03     42.0  ...   69.0      95.0     112.0        49.0     623.0
# 2018-01-04     43.0  ...  118.0     108.0     110.0        81.0     689.0
#
#             Santiago del Estero  Tierra del Fuego  Tucumán     sum  mes_año
# index
# 2018-01-02                 74.0              39.0    157.0  4666.0  2018-01
# 2018-01-03                 51.0              41.0    167.0  4577.0  2018-01
# 2018-01-04                 68.0              50.0    182.0  4773.0  2018-01
#
# [3 rows x 27 columns]

# %%
s_dec_additive = seasonal_decompose(df_ts['Córdoba'], model = 'additive', freq = 365)
s_dec_additive.plot()
plt.show()

# %%
s_dec_additive = seasonal_decompose(df_ts['Córdoba'],model = 'multiplicative', freq = 365)
s_dec_additive.plot()
plt.show()

# %% [markdown]
# ACF autocorrelacion
#
# Los lags son los retrasos, por buenas practicas se usa 40, el zero false nos dice que si vamos a incluir el valor del periodo actual, le pusimos false porque  no es necesario incluirlo  ya que la correlacion  entre un valor y si mismo siempre sera 1

# %%
import statsmodels.graphics.tsaplots as sgt 

sgt.plot_acf(df_ts["Córdoba"], lags = 40, zero = False)
plt.title('funcion ACF', size = 24)
plt.show()

# %% [markdown]
# ACP autocorrelacion parcial
#
# No considera los efectos intermedios sino los efectos de determinado periodo con el presente
#
# Podemos observar que solo los primeros 5 elementos son significativos.

# %%
sgt.plot_pacf(df_ts["Córdoba"], lags = 40, zero = False, method= ('ols'))
plt.title('funcion pacf', size = 24)
plt.show()

# %%
# Promedio movil simple

df_MA = df_ts.copy()
df_MA['tramite_fecha'] = df_MA.index
df_MA['2-months-sma-cordoba'] = df_MA['Córdoba'].rolling(window=44).mean()
df_MA['2-months-sma-sum'] = df_MA['sum'].rolling(window=44).mean()

get_line_plot(df_MA, 'tramite_fecha', "2-months-sma-cordoba", "2-months-sma-sum", "Transacciones Autos Usados Argentina 2018 - 2022 + Movil Average 2 Months")

# %% [markdown]
# # Modelo Autorregresivo
#
#
# La autocorrelacion nos va a permitir desarrollar este modelo que se basa en tener en cuenta valores pasados. Es un modelo lineal donde los valores del periodo actual son la suma de resultados pasados multiplicados por un coeficiente mas un error.
#
# El coeficiente siempre tiene que estar entre - 1 y 1. No puede ser superior en valor absoluto
#
# El residuo van a ser diferencias impredecibles, si hay un patrón se va a identificar en las variables del modelo, el residuo es la diferencia entre el valor real y el estimado

# %% [markdown]
# Ejecutamos un modelo autorregresivo de orden 1 AR(1) 1 representa un retraso y el cero representa que no tenemos en cuenta valores resiudales

# %%
# LLR Test para comparar 2 modelos
# testeamos dos modelos construyendo una funcion que nos devolvera un p valor. la hipotesis nula nos dice que los dos modelos son significativamente similares y la alternativa es que son diferentes
# DF son los grados de libertad, se sacan entre la diferencia entre los coeficientes del modelo 1 y 2.

variable = 'Córdoba'

def LLR_test(mod_1, mod_2, DF=1):
    # Buscamos las logsimilitudes de ambos modelos
    L1 = mod_1.llf
    L2 = mod_2.llf
    LR = (2*(L2-L1))
    p = chi2.sf(LR, DF).round(3)
    return p

# Comparamos modelos:
# Si son significativamente diferentes me voy a quedar con el mas simple de todos, el de menos rezagos
# Probamos el test para mas rezagos

modelos_ar = 8
modelos_resultados = []
for i in range(1 , modelos_ar + 1):
    model = ARMA(df_ts[variable], order=(i,0))
    results = model.fit()
    print ("LLR test p-value = " + str(LLR_test(results, ARMA(df_ts[variable], order=(i + 1,0)).fit())), f'AR-{i} Vs AR-{i+1}')
    
model = ARMA(df_ts[variable], order=(4,0))
results_ar_4 = model.fit()
# Nos quedamos con el modelo 4 ya que el sigueinte modelo no es significativo. incluir los precios de una semana atras nos puede dar buenos resultados. (dias habiles)
# Out:
# LLR test p-value = 0.0 AR-1 Vs AR-2
# LLR test p-value = 0.0 AR-2 Vs AR-3
# LLR test p-value = 0.0 AR-3 Vs AR-4
# LLR test p-value = 0.0 AR-4 Vs AR-5
# LLR test p-value = 0.909 AR-5 Vs AR-6
# LLR test p-value = 0.531 AR-6 Vs AR-7
# LLR test p-value = 0.172 AR-7 Vs AR-8
# LLR test p-value = 0.123 AR-8 Vs AR-9

# %%
df = df_ts[df_ts.index.year.isin(['2018','2019','2020','2021','2022'])]

# %%
df_ts.head(3)
# Out:
#            tramite_fecha  Buenos Aires  Catamarca  Chaco  Chubut  \
# index
# 2018-01-02    2018-01-02        2719.0       43.0   94.0   145.0
# 2018-01-03    2018-01-03        2809.0       45.0  141.0   134.0
# 2018-01-04    2018-01-04        2857.0       30.0  121.0   139.0
#
#             Ciudad Autónoma de Bs.As.  Corrientes  Córdoba  Entre Ríos  \
# index
# 2018-01-02                      594.0       178.0    877.0       271.0
# 2018-01-03                      672.0       184.0    737.0       285.0
# 2018-01-04                      714.0       157.0    760.0       286.0
#
#             Formosa  ...  Salta  San Juan  San Luis  Santa Cruz  Santa Fe  \
# index                ...
# 2018-01-02     44.0  ...  130.0      89.0     106.0        70.0     724.0
# 2018-01-03     42.0  ...   69.0      95.0     112.0        49.0     623.0
# 2018-01-04     43.0  ...  118.0     108.0     110.0        81.0     689.0
#
#             Santiago del Estero  Tierra del Fuego  Tucumán     sum  mes_año
# index
# 2018-01-02                 74.0              39.0    157.0  4666.0  2018-01
# 2018-01-03                 51.0              41.0    167.0  4577.0  2018-01
# 2018-01-04                 68.0              50.0    182.0  4773.0  2018-01
#
# [3 rows x 27 columns]

# %%
size_test = 22

from sklearn.model_selection import train_test_split

train, test = train_test_split(df_ts[['sum']], test_size=22, random_state=42, shuffle=False)


model_aarima = pm.auto_arima(train,
                        m=5, seasonal=False,
                        start_p=0, start_q=0, max_order=1, test='adf',error_action='ignore',  
                        suppress_warnings=True,
                        stepwise=True, trace=True)

print(model_aarima.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=21491.011, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=inf, Time=0.20 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=15460.455, Time=0.15 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=15461.083, Time=0.29 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=15461.121, Time=0.10 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=19157.709, Time=0.72 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=inf, Time=0.04 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=15463.050, Time=0.22 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=15489.150, Time=0.13 sec
#
# Best model:  ARIMA(1,0,1)(0,0,0)[0]
# Total fit time: 1.896 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 1095
# Model:               SARIMAX(1, 0, 1)   Log Likelihood               -7727.227
# Date:                Fri, 19 Aug 2022   AIC                          15460.455
# Time:                        11:15:55   BIC                          15475.450
# Sample:                             0   HQIC                         15466.129
#                                - 1095
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9997      0.001   1697.679      0.000       0.999       1.001
# ma.L1         -0.6597      0.013    -50.895      0.000      -0.685      -0.634
# sigma2      7.844e+04   1793.056     43.749      0.000    7.49e+04     8.2e+04
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.40   Jarque-Bera (JB):              1679.50
# Prob(Q):                              0.53   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.90   Skew:                            -0.74
# Prob(H) (two-sided):                  0.32   Kurtosis:                         8.88
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
model_aarima.fit(train)
# Out:
# ARIMA(order=(1, 0, 1), scoring_args={}, suppress_warnings=True,
#       with_intercept=False)

# %%
forecast = model_aarima.predict(n_periods = size_test, return_conf_int=True)

# %%
forecast_df = pd.DataFrame(forecast[0],index = test.index, columns=['Prediction'])

# %%
fig, ax = plt.subplots(figsize=(15,9))
ax.plot(train[900:])
ax.plot(test)
ax.plot(forecast_df)
ax.set_title("Final Forecast")
ax.figure.autofmt_xdate()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,9))
ax.plot(train)
ax.plot(test)
ax.plot(forecast_df)
ax.set_title("Final Forecast")
ax.figure.autofmt_xdate()
plt.show()

# %%
model_aarima.plot_diagnostics(figsize=(14,10))
plt.show()

# %%
df_mes.index = df_mes['mes_año']

# %%
df_mes.head(5)
# Out:
#               mes_año  Buenos Aires  Catamarca  Chaco  Chubut  \
# mes_año
# 2018-01-01 2018-01-01        2762.0       39.0  128.0   158.0
# 2018-02-01 2018-02-01        2748.0       29.0  117.0   157.0
# 2018-03-01 2018-03-01        2817.0       40.0  122.0   154.0
# 2018-04-01 2018-04-01        2799.0       35.0  122.0   154.0
# 2018-05-01 2018-05-01        2756.0       36.0  113.0   151.0
#
#             Ciudad Autónoma de Bs.As.  Corrientes  Córdoba  Entre Ríos  \
# mes_año
# 2018-01-01                      735.0       150.0    794.0       297.0
# 2018-02-01                      680.0       144.0    835.0       296.0
# 2018-03-01                      730.0       137.0    841.0       318.0
# 2018-04-01                      712.0       132.0    841.0       306.0
# 2018-05-01                      701.0       133.0    835.0       283.0
#
#             Formosa  ...  Río Negro  Salta  San Juan  San Luis  Santa Cruz  \
# mes_año              ...
# 2018-01-01     47.0  ...      162.0  112.0     100.0     110.0        65.0
# 2018-02-01     44.0  ...      167.0  101.0      94.0     113.0        65.0
# 2018-03-01     40.0  ...      162.0   94.0      89.0     108.0        66.0
# 2018-04-01     38.0  ...      159.0  100.0      90.0     113.0        62.0
# 2018-05-01     38.0  ...      163.0   96.0      95.0     110.0        58.0
#
#             Santa Fe  Santiago del Estero  Tierra del Fuego  Tucumán     sum
# mes_año
# 2018-01-01     664.0                 67.0              44.0    160.0  4726.0
# 2018-02-01     689.0                 69.0              41.0    140.0  4634.0
# 2018-03-01     707.0                 59.0              46.0    132.0  4705.0
# 2018-04-01     692.0                 55.0              46.0    137.0  4701.0
# 2018-05-01     673.0                 60.0              47.0    144.0  4653.0
#
# [5 rows x 26 columns]

# %%
df_mes['Córdoba'] = np.log(df_mes.Córdoba.values)
df_mes['year']    = [d.year for d in df_mes.index]
df_mes['month']   = [d.strftime('%b') for d in df_mes.index]
years = df_mes['year'].unique()

# %%
# Preparamos los colores:
np.random.seed(100)
mycolors = np.random.choice(list(mpl.colors.XKCD_COLORS.keys()), len(years), replace=False)

# Ploteamos
plt.figure(figsize=(16,12), dpi= 80)
for i, y in enumerate(years):
    plt.plot('month', 'Córdoba', data=df_mes.loc[df_mes.year==y, :], color=mycolors[i], label=y)
    plt.text(df_mes.loc[df_mes.year==y, :].shape[0] -.9, df_mes.loc[df_mes.year==y, 'Córdoba'][-1:].values[0], y, fontsize=12, color=mycolors[i])


plt.gca().set(xlim=(-0.3, 11), ylim=(6.4, 6.95), ylabel='$Ventas$', xlabel='$Mes$')
plt.yticks(fontsize=12, alpha=.7)
plt.title("Visualizacion de Estacionalidad", fontsize=20);

# %%
df_mes.head(2)
# Out:
#               mes_año  Buenos Aires  Catamarca  Chaco  Chubut  \
# mes_año
# 2018-01-01 2018-01-01        2762.0       39.0  128.0   158.0
# 2018-02-01 2018-02-01        2748.0       29.0  117.0   157.0
#
#             Ciudad Autónoma de Bs.As.  Corrientes   Córdoba  Entre Ríos  \
# mes_año
# 2018-01-01                      735.0       150.0  6.677083       297.0
# 2018-02-01                      680.0       144.0  6.727432       296.0
#
#             Formosa  ...  San Juan  San Luis  Santa Cruz  Santa Fe  \
# mes_año              ...
# 2018-01-01     47.0  ...     100.0     110.0        65.0     664.0
# 2018-02-01     44.0  ...      94.0     113.0        65.0     689.0
#
#             Santiago del Estero  Tierra del Fuego  Tucumán     sum  year  \
# mes_año
# 2018-01-01                 67.0              44.0    160.0  4726.0  2018
# 2018-02-01                 69.0              41.0    140.0  4634.0  2018
#
#             month
# mes_año
# 2018-01-01    Jan
# 2018-02-01    Feb
#
# [2 rows x 28 columns]

# %%
df_ts.head(2)
# Out:
#            tramite_fecha  Buenos Aires  Catamarca  Chaco  Chubut  \
# index
# 2018-01-02    2018-01-02        2719.0       43.0   94.0   145.0
# 2018-01-03    2018-01-03        2809.0       45.0  141.0   134.0
#
#             Ciudad Autónoma de Bs.As.  Corrientes  Córdoba  Entre Ríos  \
# index
# 2018-01-02                      594.0       178.0    877.0       271.0
# 2018-01-03                      672.0       184.0    737.0       285.0
#
#             Formosa  ...  Salta  San Juan  San Luis  Santa Cruz  Santa Fe  \
# index                ...
# 2018-01-02     44.0  ...  130.0      89.0     106.0        70.0     724.0
# 2018-01-03     42.0  ...   69.0      95.0     112.0        49.0     623.0
#
#             Santiago del Estero  Tierra del Fuego  Tucumán     sum  mes_año
# index
# 2018-01-02                 74.0              39.0    157.0  4666.0  2018-01
# 2018-01-03                 51.0              41.0    167.0  4577.0  2018-01
#
# [2 rows x 27 columns]

# %%
df_ts.columns
# Out:
# Index(['tramite_fecha', 'Buenos Aires', 'Catamarca', 'Chaco', 'Chubut',
#        'Ciudad Autónoma de Bs.As.', 'Corrientes', 'Córdoba', 'Entre Ríos',
#        'Formosa', 'Jujuy', 'La Pampa', 'La Rioja', 'Mendoza', 'Misiones',
#        'Neuquén', 'Río Negro', 'Salta', 'San Juan', 'San Luis', 'Santa Cruz',
#        'Santa Fe', 'Santiago del Estero', 'Tierra del Fuego', 'Tucumán', 'sum',
#        'mes_año'],
#       dtype='object')

# %%
get_line_plot(df_ts, "tramite_fecha", "Buenos Aires", "Córdoba", "Transacciones Autos Usados Argentina 2018 - 2022", rolling = True, periods = 5*3)
