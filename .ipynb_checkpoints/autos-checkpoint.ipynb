# %%
import pandas as pd
import numpy as np
import plotly.io as pio
import plotly.express as px
import plotly.figure_factory as ff
import matplotlib.pyplot as plt
import matplotlib.patches
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics
from math import sqrt
from io import BytesIO
from zipfile import ZipFile
from urllib.request import urlopen
from os import listdir
import warnings

warnings.filterwarnings('ignore')

# %% [markdown]
# Descomprime los ZIP y descarga los Csv

# %%
with open('folder.txt', 'r') as folder:
    lines = folder.readlines()
    
folder_archivos =  ' '.join(lines)

csv_files = []

# %%
def find_csv_filenames( path_to_dir, suffix=".csv" ):
    filenames = listdir(path_to_dir)
    return [ filename for filename in filenames if filename.endswith( suffix ) ]

csv_files = [l for l in find_csv_filenames(folder_archivos, suffix=".csv" ) if 'autos' in l]

# %%
with open('urls.txt', 'r') as folder_urls:
    lines_urls = folder_urls.readlines()

if len(csv_files) == 0:
    zipurls = lines_urls

    for zipurl in zipurls:
        with urlopen(zipurl) as zipresp:
            with ZipFile(BytesIO(zipresp.read())) as zfile:
                zfile.extractall(folder_archivos)

# %% [markdown]
# Lee todos los Csv de la carpeta

# %%
list_data_frames = []

for file in csv_files:
    df_new = pd.read_csv(file)
    list_data_frames.append(df_new)

# %%
df = pd.concat(list_data_frames, ignore_index=True)

df.shape
# Out:
# (7414431, 27)

# %%
df.head(6)
# Out:
#              tramite_tipo tramite_fecha fecha_inscripcion_inicial  \
# 0  TRANSFERENCIA NACIONAL    2018-09-06                1999-07-08
# 1  TRANSFERENCIA NACIONAL    2018-09-19                1994-07-05
# 2  TRANSFERENCIA NACIONAL    2018-09-24                2008-06-04
# 3  TRANSFERENCIA NACIONAL    2018-09-28                2009-10-13
# 4  TRANSFERENCIA NACIONAL    2018-09-28                1979-05-30
# 5  TRANSFERENCIA NACIONAL    2018-09-28                1979-05-30
#
#    registro_seccional_codigo registro_seccional_descripcion  \
# 0                       1001                   ADROGUE Nº 1
# 1                       1001                   ADROGUE Nº 1
# 2                       1001                   ADROGUE Nº 1
# 3                       1001                   ADROGUE Nº 1
# 4                       1001                   ADROGUE Nº 1
# 5                       1001                   ADROGUE Nº 1
#
#   registro_seccional_provincia automotor_origen  automotor_anio_modelo  \
# 0                 Buenos Aires         Nacional                 1999.0
# 1                 Buenos Aires         Nacional                 1994.0
# 2                 Buenos Aires         Nacional                 2008.0
# 3                 Buenos Aires         Nacional                 2009.0
# 4                 Buenos Aires         Nacional                 1979.0
# 5                 Buenos Aires         Nacional                 1979.0
#
#   automotor_tipo_codigo automotor_tipo_descripcion  ...  \
# 0                   NaN                      SEDAN  ...
# 1                   NaN             BERLINA 5 PTAS  ...
# 2                   NaN                 FURGON 600  ...
# 3                   NaN                 FURGON 600  ...
# 4                   NaN               MICROOMNIBUS  ...
# 5                   NaN               MICROOMNIBUS  ...
#
#   titular_domicilio_localidad titular_domicilio_provincia titular_genero  \
# 0            VILLA LA FLORIDA                BUENOS AIRES      Masculino
# 1                     BURZACO                BUENOS AIRES      Masculino
# 2             VIRREY DEL PINO                BUENOS AIRES      Masculino
# 3                  LONGCHAMPS                BUENOS AIRES      Masculino
# 4            LA BANDA PADILLA                BUENOS AIRES      Masculino
# 5         C.AUTONOMA DE BS.AS                BUENOS AIRES      No aplica
#
#   titular_anio_nacimiento  titular_pais_nacimiento  \
# 0                  1995.0                Argentina
# 1                  1965.0                Argentina
# 2                  1990.0                Argentina
# 3                  1963.0                Argentina
# 4                  1971.0                Argentina
# 5                  1994.0                No aplica
#
#   titular_porcentaje_titularidad titular_domicilio_provincia_indec_id  \
# 0                            100                                  6.0
# 1                            100                                  6.0
# 2                            100                                  6.0
# 3                            100                                  6.0
# 4                            100                                  6.0
# 5                            100                                  6.0
#
#   titular_pais_nacimiento_indec_id titular_domicilio_provincia_id  \
# 0                              ARG                            NaN
# 1                              ARG                            NaN
# 2                              ARG                            NaN
# 3                              ARG                            NaN
# 4                              ARG                            NaN
# 5                              NaN                            NaN
#
#   titular_pais_nacimiento_id
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# 5                        NaN
#
# [6 rows x 27 columns]

# %%
df_tipo = df.groupby(['automotor_tipo_descripcion'])['automotor_tipo_descripcion'].count().reset_index(name="count").sort_values(by = 'count', ascending = False)

df_tipo.head()
# Out:
#      automotor_tipo_descripcion    count
# 9787            SEDAN 5 PUERTAS  1185415
# 9760               SEDAN 5 PTAS  1158117
# 9618               SEDAN 4 PTAS   977265
# 9668            SEDAN 4 PUERTAS   741937
# 8456                    PICK-UP   612201

# %%
df_año = df.groupby(['automotor_anio_modelo'])['automotor_anio_modelo'].count().reset_index(name="count")

df_año = df_año.loc[(df_año['automotor_anio_modelo'] >= 1970) & (df_año['automotor_anio_modelo'] <= 2022)].sort_values(by = 'automotor_anio_modelo', ascending = False)

df_año['automotor_anio_modelo'] = df_año['automotor_anio_modelo'].astype(object)

# %%
df_año.head()
# Out:
#     automotor_anio_modelo   count
# 118                  2022    5142
# 117                  2021   27642
# 116                  2020   44646
# 115                  2019   92563
# 114                  2018  224294

# %%
def plot_hbar(df, x, y, n, title):
    fig = px.bar(df, 
                 x=x, y=y, 
                 text=x, orientation='v', width=700, color = x)
    fig.update_layout(title=title, xaxis_title=x, yaxis_title=y, 
                      xaxis={'categoryorder':'total ascending'},
                      uniformtext_minsize=8, uniformtext_mode='hide')
    fig.show()
    
#plot_hbar(df_año, 'automotor_anio_modelo', 'count',  15, 'Cantidad de Autos por Modelo (Año)')

# %%
#plot_hbar(df_tipo, 'automotor_tipo_descripcion', 'count',  15, 'Cantidad de Autos por Modelo (Año)')

# %%
df["tramite_fecha"] = pd.to_datetime(df["tramite_fecha"])

df = df.pivot_table(index='tramite_fecha',
               columns='registro_seccional_provincia',
               aggfunc=len,
               fill_value=0)

df.columns = df.columns.droplevel(0) 
df.columns.name = None              
df = df.reset_index()    

df = df.loc[:,~df.apply(lambda x: x.duplicated(),axis=1).all()].copy()


df.head(5)
# Out:
#   tramite_fecha  Buenos Aires  Catamarca  Chaco  Chubut  \
# 0    2018-01-02          2719         43     94     145
# 1    2018-01-03          2809         45    141     134
# 2    2018-01-04          2857         30    121     139
# 3    2018-01-05          2884         46    122     162
# 4    2018-01-06             7          0      0       0
#
#    Ciudad Autónoma de Bs.As.  Corrientes  Córdoba  Entre Ríos  Formosa  ...  \
# 0                        594         178      877         271       44  ...
# 1                        672         184      737         285       42  ...
# 2                        714         157      760         286       43  ...
# 3                        757         179      838         300       56  ...
# 4                          0           0        0           0        0  ...
#
#    Neuquén  Río Negro  Salta  San Juan  San Luis  Santa Cruz  Santa Fe  \
# 0      123        182    130        89       106          70       724
# 1      141        182     69        95       112          49       623
# 2      163        169    118       108       110          81       689
# 3      161        171    103       121       116          72       643
# 4        0         13      5         0         0           6         0
#
#    Santiago del Estero  Tierra del Fuego  Tucumán
# 0                   74                39      157
# 1                   51                41      167
# 2                   68                50      182
# 3                   71                55      149
# 4                    0                 0        0
#
# [5 rows x 25 columns]

# %%
#df_dolar = pd.read_csv('dolarfinal.csv')

#df_dolar.head(5)

# %%
#df.set_index('tramite_fecha', inplace = True)

# %%
#df_dolar.set_index('Fecha', inplace = True)

# %%
#df = pd.merge(df, df_dolar, left_index=True, right_index=True)

# %%
df["sum"] = df[df.columns[1:]].sum(axis=1)

# %%
df["sum"].describe()
# Out:
# count    1315.000000
# mean     5638.350570
# std      2798.529663
# min         1.000000
# 25%      6003.000000
# 50%      6866.000000
# 75%      7338.500000
# max      8877.000000
# Name: sum, dtype: float64

# %%
df_copy = df.copy()
df_g = df[df['sum'] > 6000]

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
plt.rcParams["figure.figsize"] = (10,6)

fig, ax1 = plt.subplots()
ax2 = ax1.twinx()

ax1.plot(df_g['tramite_fecha'], np.log(df_g['Ciudad Autónoma de Bs.As.']), label="Ciudad Autónoma de Bs.As.",  c="b");
ax1.plot(df_g['tramite_fecha'], np.log(df_g['Córdoba']), label="Córdoba",  c="r");

plt.title('Transferencias de autos\nTrámites de transferencia de automotores inscriptos en los Registros Seccionales de la Propiedad del Automotor y Créditos Prendarios.')
plt.show()

# %%
fig = plt.figure()
ax  = plt.axes()

ax.plot(df_g['tramite_fecha'], df_g['Ciudad Autónoma de Bs.As.'].div(df_g['Ciudad Autónoma de Bs.As.'].iloc[0]).mul(100), label="Ciudad Autónoma de Bs.As.",  c="b");
ax.plot(df_g['tramite_fecha'], df_g['Córdoba'].div(df_g['Córdoba'].iloc[0]).mul(100), label="cordoba_norm",  c="y");
ax.plot(df_g['tramite_fecha'], df_g['Santa Fe'].div(df_g['Santa Fe'].iloc[0]).mul(100), label="santafe_norm",  c="r");
ax.plot(df_g['tramite_fecha'], df_g['Corrientes'].div(df_g['Corrientes'].iloc[0]).mul(100), label="corrientes_norm",  c="g");
plt.title('Transferencias de autos\nTrámites de transferencia de automotores inscriptos en los Registros Seccionales de la Propiedad del Automotor y Créditos Prendarios.')
plt.show()

# %%
df['año'] = pd.DatetimeIndex(df['tramite_fecha']).year
df['mes_año'] = pd.to_datetime(df['tramite_fecha']).dt.to_period('M')
df.head(5)
# Out:
#   tramite_fecha  Buenos Aires  Catamarca  Chaco  Chubut  \
# 0    2018-01-02          2719         43     94     145
# 1    2018-01-03          2809         45    141     134
# 2    2018-01-04          2857         30    121     139
# 3    2018-01-05          2884         46    122     162
# 4    2018-01-06             7          0      0       0
#
#    Ciudad Autónoma de Bs.As.  Corrientes  Córdoba  Entre Ríos  Formosa  ...  \
# 0                        594         178      877         271       44  ...
# 1                        672         184      737         285       42  ...
# 2                        714         157      760         286       43  ...
# 3                        757         179      838         300       56  ...
# 4                          0           0        0           0        0  ...
#
#    San Juan  San Luis  Santa Cruz  Santa Fe  Santiago del Estero  \
# 0        89       106          70       724                   74
# 1        95       112          49       623                   51
# 2       108       110          81       689                   68
# 3       121       116          72       643                   71
# 4         0         0           6         0                    0
#
#    Tierra del Fuego  Tucumán   sum   año  mes_año
# 0                39      157  7385  2018  2018-01
# 1                41      167  7386  2018  2018-01
# 2                50      182  7630  2018  2018-01
# 3                55      149  7796  2018  2018-01
# 4                 0        0    31  2018  2018-01
#
# [5 rows x 28 columns]

# %%
from plotly.subplots import make_subplots
def get_line_plot(dataframe, x, y1, y2, titulo):
    subfig = make_subplots(specs=[[{"secondary_y": True}]])

    fig  = px.line(dataframe, x=x, y=y1)

    fig2 = px.line(dataframe, x=x,y=y2)

    fig.update_layout(xaxis_rangeslider_visible=True)
    fig.update_traces(showlegend=True,name=y1,line_color='red', line_width=1)
    fig2.update_traces(showlegend=True,name=y2,line_color='#0000ff', line_width=1) #, yaxis="y2"
    subfig.add_traces(fig.data + fig2.data)

    subfig.layout.xaxis.title ="Periodos"
    subfig.layout.yaxis.title ="Cantidad"
    subfig.layout.yaxis2.title="Cantidad"
    subfig.layout.title=titulo 

    return subfig.show()

get_line_plot(df_g, "tramite_fecha", "Ciudad Autónoma de Bs.As.", "Córdoba", "Transacciones Autos Usados Argentina 2018 - 2022")

# %%
df_g.head()
# Out:
#   tramite_fecha  Buenos Aires  Catamarca  Chaco  Chubut  \
# 0    2018-01-02          2719         43     94     145
# 1    2018-01-03          2809         45    141     134
# 2    2018-01-04          2857         30    121     139
# 3    2018-01-05          2884         46    122     162
# 6    2018-01-08          2711         35    130     165
#
#    Ciudad Autónoma de Bs.As.  Corrientes  Córdoba  Entre Ríos  Formosa  ...  \
# 0                        594         178      877         271       44  ...
# 1                        672         184      737         285       42  ...
# 2                        714         157      760         286       43  ...
# 3                        757         179      838         300       56  ...
# 6                        699         162      803         293       47  ...
#
#    Río Negro  Salta  San Juan  San Luis  Santa Cruz  Santa Fe  \
# 0        182    130        89       106          70       724
# 1        182     69        95       112          49       623
# 2        169    118       108       110          81       689
# 3        171    103       121       116          72       643
# 6        188    142        96        71          62       641
#
#    Santiago del Estero  Tierra del Fuego  Tucumán   sum
# 0                   74                39      157  7385
# 1                   51                41      167  7386
# 2                   68                50      182  7630
# 3                   71                55      149  7796
# 6                   85                39      137  7393
#
# [5 rows x 26 columns]

# %%
columnas = []
values   = []

for i in range(len(df_g.drop(columns = ['sum']).columns)):
    try:
        i += 1
        columnas.append(df_g.drop(columns = ['sum']).columns[i])
        values.append(df_g[df_g.drop(columns = ['sum']).columns[i]].sum())
    except:
        continue

df_group = pd.DataFrame({'indice': columnas, 'n' : values}).sort_values(by = 'n', ascending = False)

# %%
df_group.head()
# Out:
#                        indice        n
# 0                Buenos Aires  2613343
# 6                     Córdoba   821752
# 20                   Santa Fe   669126
# 4   Ciudad Autónoma de Bs.As.   658095
# 12                    Mendoza   369664

# %%
plot_hbar(df_group, 'indice', 'n',  15,'Transacciones')

# %%
df_mes = df.groupby('mes_año')[df.columns.drop(["tramite_fecha", 'año', 'mes_año'])].sum().reset_index()

# %%
'''
from datetime import datetime

año_string = "20200704"

dt   = datetime.strptime(año_string,'%Y%m%d').date()

print(dt)


min_seg = "02:00"

dt   = datetime.strptime(min_seg,'%M:%S').time()
        
        
print(dt)
'''
# Out:
# '\nfrom datetime import datetime\n\naño_string = "20200704"\n\ndt   = datetime.strptime(año_string,\'%Y%m%d\').date()\n\nprint(dt)\n\n\nmin_seg = "02:00"\n\ndt   = datetime.strptime(min_seg,\'%M:%S\').time()\n        \n        \nprint(dt)\n'

# %%
df_mes["mes_año"] = [d.to_timestamp() for d in df_mes["mes_año"].values]

# %%
get_line_plot(df_mes, "mes_año", "Ciudad Autónoma de Bs.As.", "Córdoba", "Transacciones Autos Usados Argentina 2018 - 2022 Datos Mensuales")

# %% [markdown]
# Hacemos un grafico QQ Plot que se  utiliza para explicar la distribucion de un conjunto de datos
#
# En el eje de las Y estan los precios de los valores,
# ordenados de menor a mayor, en el eje de las X estan los cuantiles teoricos que miden a
# cuantas desviaciones estandard de la media esta cada uno de los valores.
# La linea roja representa como se deberian distribuir los valores si siguiera una distribucion normal.
# En este caso en el valor 500 podemos ver una gran diferencia,
# por lo tanto los datos no se distribuyen de forma normal y no podremos usar la serie para pronosticos
# del futuro usando la distribucion normal.

# %%
import scipy.stats

scipy.stats.probplot(df_mes["Córdoba"], plot = plt)
plt.title('QQ Plot', size = 24)
plt.show()

# %%
df_mes["mes_año"] = pd.to_datetime(df_mes["mes_año"])
df_mes['año'] = pd.to_datetime(df_mes["mes_año"]).dt.year
df_mes.to_csv(r'cars.csv')

# %%
df_filter = df_mes[(df_mes['año'] != 2020)]

# %% [markdown]
# # Inicio del Modelo

# %% [markdown]
# Se eliminan todas las filas donde no hay transacciones

# %%
df_copy.head()
# Out:
#   tramite_fecha  Buenos Aires  Catamarca  Chaco  Chubut  \
# 0    2018-01-02          2719         43     94     145
# 1    2018-01-03          2809         45    141     134
# 2    2018-01-04          2857         30    121     139
# 3    2018-01-05          2884         46    122     162
# 4    2018-01-06             7          0      0       0
#
#    Ciudad Autónoma de Bs.As.  Corrientes  Córdoba  Entre Ríos  Formosa  ...  \
# 0                        594         178      877         271       44  ...
# 1                        672         184      737         285       42  ...
# 2                        714         157      760         286       43  ...
# 3                        757         179      838         300       56  ...
# 4                          0           0        0           0        0  ...
#
#    Río Negro  Salta  San Juan  San Luis  Santa Cruz  Santa Fe  \
# 0        182    130        89       106          70       724
# 1        182     69        95       112          49       623
# 2        169    118       108       110          81       689
# 3        171    103       121       116          72       643
# 4         13      5         0         0           6         0
#
#    Santiago del Estero  Tierra del Fuego  Tucumán   sum
# 0                   74                39      157  7385
# 1                   51                41      167  7386
# 2                   68                50      182  7630
# 3                   71                55      149  7796
# 4                    0                 0        0    31
#
# [5 rows x 26 columns]

# %%
from pandas.tseries.offsets import BDay

isBusinessDay = BDay().onOffset

match_series = pd.to_datetime(df_copy['tramite_fecha']).map(isBusinessDay)

df_copy = df_copy[match_series]

# %% [markdown]
# Podemos observar que todavia hay datos con valores 0. Se eliminan estas filas y se filtran por valores mayor a 50.

# %%
get_line_plot(df_copy, "tramite_fecha", "Ciudad Autónoma de Bs.As.", "Córdoba", "Transacciones Autos Usados Argentina 2018 - 2022 Datos Diarios (Sin fin de semana)")

# %%
df_copy = df_copy[(df_copy['Ciudad Autónoma de Bs.As.']>= 50) & (df_copy['Córdoba']>= 50)]

get_line_plot(df_copy, "tramite_fecha", "Ciudad Autónoma de Bs.As.", "Córdoba", "Transacciones Autos Usados Argentina 2018 - 2022 Datos Diarios (Sin fin de semana)")

# %% [markdown]
# Desde el 19 de marzo al 22 de abril no contamos con datos. Si bien no es buena practica en series de tiempo alterar los datos en este caso, la pandemia ha alterado todas las series temporales.
# Para este caso se va a tener en cuenta los promedios de los otros años para esas fechas asi podemos completar al serie temporal.

# %%
def get_dataframe(values, desde, hasta, years):
    data_frames = []
    for year in years:
        df_append = df_copy.loc[(df_copy['tramite_fecha'].dt.strftime('%m-%d') >= desde) & (df_copy['tramite_fecha'].dt.strftime('%m-%d') <= hasta) & (df_copy['tramite_fecha'].dt.strftime('%Y') == year)][values]
        data_frames.append(df_append)
    df_final_concat = pd.concat(data_frames, ignore_index=True)
    df_final_concat['month_day'] = df_final_concat['tramite_fecha'].dt.strftime('%m-%d')
    return df_final_concat


df_final_concat = get_dataframe(['tramite_fecha','Ciudad Autónoma de Bs.As.' , 'Córdoba'], '03-28', '04-22', ['2018', '2019', '2021', '2022'])

# %%
df_final_concat.head()
# Out:
#   tramite_fecha  Ciudad Autónoma de Bs.As.  Córdoba month_day
# 0    2018-03-28                        839      872     03-28
# 1    2018-04-03                        664      863     04-03
# 2    2018-04-04                        788      981     04-04
# 3    2018-04-05                        737      887     04-05
# 4    2018-04-06                        733      880     04-06

# %% [markdown]
# Se agrupa por mes y dia, se saca el promedio y se agrega el año 2020:

# %%
df_values = df_final_concat.groupby('month_day' ,as_index = False).mean().round(0)

df_values['month_day'] = df_values.apply(lambda x: '2020-' + str(x['month_day']), axis = 1)

df_values['month_day'] = pd.to_datetime(df_values['month_day'], format='%Y-%m-%d')

# %%
# filtro mensual

# df_ts_1 = df_copy[(df_copy['tramite_fecha'].dt.strftime('%m-%Y') != '04-2020') & (df_copy['tramite_fecha'].dt.strftime('%m-%Y') != '05-2020') & (df_copy['tramite_fecha'].dt.strftime('%m-%Y') != '06-2020')][['tramite_fecha','Ciudad Autónoma de Bs.As.' , 'Córdoba']]

# filtro de la funcion get_dataframe

df_ts_1 = df_copy[['tramite_fecha','Ciudad Autónoma de Bs.As.' , 'Córdoba']]

df_values.rename(columns = {'month_day':'tramite_fecha'}, inplace = True)

df_ts = pd.concat([df_ts_1, df_values], ignore_index=True)

df_ts.to_csv('df_ts.csv')

# %%
df_ts.sort_values(by = 'tramite_fecha', inplace = True)

# %%
get_line_plot(df_ts, "tramite_fecha", "Ciudad Autónoma de Bs.As.", "Córdoba", "Transacciones Autos Usados Argentina 2018 - 2022 Datos Diarios")

# %% [markdown]
# Creamos la variable date como datetime. Transformamos la fecha como datetime para usarla como indice en la serie temporal

# %%
df_ts.dtypes
# Out:
# tramite_fecha                datetime64[ns]
# Ciudad Autónoma de Bs.As.           float64
# Córdoba                             float64
# dtype: object

# %%
import datetime

#df_ts['tramite_fecha'] = df_ts.apply(lambda x: datetime.datetime.strptime(x['tramite_fecha'], "%Y-%m-%d").strftime("%d-%m-%Y"), axis = 1)

df_ts.head(5)
# Out:
#   tramite_fecha  Ciudad Autónoma de Bs.As.  Córdoba
# 0    2018-01-02                      594.0    877.0
# 1    2018-01-03                      672.0    737.0
# 2    2018-01-04                      714.0    760.0
# 3    2018-01-05                      757.0    838.0
# 4    2018-01-08                      699.0    803.0

# %%
df_ts.columns
# Out:
# Index(['tramite_fecha', 'Ciudad Autónoma de Bs.As.', 'Córdoba'], dtype='object')

# %%
df_ts['date'] = pd.to_datetime(df_ts.tramite_fecha, dayfirst = True)

df_ts.set_index('date', inplace=True)

# %% [markdown]
# Colocamos como frecuencia dia
#
# h = hora, w = semanales, d = diarios, m = mensuales, a = anuales, b = dias de negocios (no agrega los fines de semana).

# %% [markdown]
# Los faltantes los completamos con el metodo fillna, relleno de NA.El metodo de ffill, front filling, significa relleno frontal, le asigna al valor faltante el valor del periodo posterior, muy util para series temporales. El otro metodo es el bfill donde usamos el periodo previo.

# %%
df_ts["Córdoba"]= df_ts["Córdoba"].fillna(method='ffill')

# %%
df_ts.head(5)
# Out:
#            tramite_fecha  Ciudad Autónoma de Bs.As.  Córdoba
# date
# 2018-01-02    2018-01-02                      594.0    877.0
# 2018-01-03    2018-01-03                      672.0    737.0
# 2018-01-04    2018-01-04                      714.0    760.0
# 2018-01-05    2018-01-05                      757.0    838.0
# 2018-01-08    2018-01-08                      699.0    803.0

# %% [markdown]
# Eliminamos las columnas que no vamos a usar por ahora:

# %%
del df_ts['Ciudad Autónoma de Bs.As.']
del df_ts['tramite_fecha']

# %% [markdown]
# Separamos los datos para entrenar y para testear

# %%
# Sacamos el 80% para entrenar

# size = int(len(df_ts)*0.8)

# Desde el comienzo de los datos hasta un punto

# df = df_ts.iloc[0:size]

# Desde el punto hasta el ultimo

# df_test = df_ts.iloc[size:len(df_ts)]

# print('El ultimo valor de df es: ',df.tail(1), 'y el test comienza en: ',df_test.head(1))

# %% [markdown]
# Prueba de Dickey Fuller para verificar si un conjunto de datos proviene de un proceso estacionario o no.
#
# La prueba esta basada en un contraste de hipotesis.
#
#
# Hipotesis Nula: La serie no es estacionaria
# Hipotesis Alternativa: La serie es estacionaria

# %%
import statsmodels.tsa.stattools as sts
from statsmodels.tsa.seasonal import seasonal_decompose
import seaborn as sns


def get_adfuller(value):
    if sts.adfuller(value)[0] > sts.adfuller(value)[4]['1%']:
        print('No rechazamos hipotesis nula, la serie NO ES estacionaria a un nivel de significacion del 1 % con un numero de retrasos de: ', sts.adfuller(value)[2])

    elif sts.adfuller(value)[0] > sts.adfuller(value)[4]['5%']:
        print('No rechazamos hipotesis nula, la serie NO ES estacionaria a un nivel de significacion del 5 % con un numero de retrasos de: ', sts.adfuller(value)[2])

    elif sts.adfuller(value)[0] > sts.adfuller(value)[4]['10%']:
        print('No rechazamos hipotesis nula, la serie NO ES estacionaria a un nivel de significacion del 10 % con un numero de retrasos de: ', sts.adfuller(value)[2])

    else: print('La serie ES estacionaria')
    return None


get_adfuller(df_ts["Córdoba"])
# Out:
# La serie ES estacionaria

# %% [markdown]
# Estacionalidad:
#
# Sugiere que ciertas tendencias aparecerán de forma cíclica, por ejemplo, las temperaturas suben y bajan a lo largo del tiempo. La series se pueden descomponer bajo efecto tendencia donde podemos quitar un patrón sostenido en los datos, la estacional los efectos cíclicos y el residual el error entre los datos reales y el modelo que estamos ejecutando.
#
# La descomposición clásica puede ser aditiva o multiplicativa, en la aditiva podemos suponer que en cualquier momento del tiempo el valor observado es la suma de la tendencia, el objeto estacional y el efecto residual para ese periodo.
#
# La descomposición multiplicativa nos dice que la serie original es un producto de los tres efectos anteriories.

# %%
df_ts.head()
# Out:
#             Córdoba
# date
# 2018-01-02    877.0
# 2018-01-03    737.0
# 2018-01-04    760.0
# 2018-01-05    838.0
# 2018-01-08    803.0

# %%
#df.index = df["tramite_fecha"]

# %%
#df_ts.index = df_ts.index.to_period("D")

# %%
#df = df[["Córdoba"]]

# %%
#df.index = df.index.to_timestamp()

# %%
df_ts.sort_index(inplace=True)
s_dec_additive = seasonal_decompose(df_ts,model = 'additive', freq=365)
s_dec_additive.plot()
plt.show()

# %%
s_dec_additive = seasonal_decompose(df_ts,model = 'multiplicative', freq=365)
s_dec_additive.plot()
plt.show()

# %% [markdown]
# ACF autocorrelacion
#
# Los lags son los retrasos, por buenas practicas se usa 40, el zero false nos dice que si vamos a incluir el valor del periodo actual, le pusimos false porque  no es necesario incluirlo  ya que la correlacion  entre un valor y si mismo siempre sera 1

# %%
import statsmodels.graphics.tsaplots as sgt 

sgt.plot_acf(df_ts["Córdoba"], lags = 40, zero = False)
plt.title('funcion ACF', size = 24)
plt.show()

# %% [markdown]
# ACP autocorrelacion parcial
#
# no considera los efectos intermedios sino los efectos de determinado periodo con el presente
#
# Podemos observar que solo los primeros elementos son significativos.Principalmente el primero de todos

# %%
sgt.plot_pacf(df_ts["Córdoba"], lags = 40, zero = False, method= ('ols'))
plt.title('funcion pacf', size = 24)
plt.show()

# %%
# Promedio movil simple

df_ts['6-month-sma'] = df_ts['Córdoba'].rolling(window=6).mean()

df_ts['12-month-sma'] = df_ts['Córdoba'].rolling(window=12).mean()


df_ts.plot(figsize=(12,8));

# %% [markdown]
# # Modelo Autorregresivo
#
#
# La autocorrelacion nos va a permitir desarrollar este modelo que se basa en tener en cuenta valores pasados. Es un modelo lineal donde los valores del periodo actual son la suma de resultados pasados multiplicados por un coeficiente mas un error.
#
# El coeficiente siempre tiene que estar entre - 1 y 1. No puede ser superior en valor absoluto
#
# El residuo van a ser diferencias impredecibles, si hay un patrón se va a identificar en las variables del modelo, el residuo es la diferencia entre el valor real y el estimado

# %%
#df.index = df.index.to_period("D")

# %%
#df_test.index = df_test.index.to_period("D")

# %% [markdown]
# Podemos observar que la constante es 815.0868 y el del rezago es  0.7398. Los erroes estandard son 9.987. Vemos que el p valor (P>|z|) es cero, comparado con niveles de significacion podemos decir que son significativos

# %%
from statsmodels.tsa.arima_model import ARMA
from scipy.stats.distributions import chi2

# Ejecutamos un modelo autorregresivo de orden 1

# AR(1)

# 1 representa un retraso y el cero representa que no tenemos en cuenta valores resiudales

model_ar = ARMA(df_ts['Córdoba'], order=(1,0))

results_ar = model_ar.fit()

results_ar.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                Córdoba   No. Observations:                 1093
# Model:                     ARMA(1, 0)   Log Likelihood               -6253.323
# Method:                       css-mle   S.D. of innovations             73.844
# Date:                Sun, 24 Jul 2022   AIC                          12512.645
# Time:                        23:17:04   BIC                          12527.635
# Sample:                             0   HQIC                         12518.318
#
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const           814.8152      8.458     96.340      0.000     798.238     831.392
# ar.L1.Córdoba     0.7366      0.020     36.056      0.000       0.697       0.777
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.3576           +0.0000j            1.3576            0.0000
# -----------------------------------------------------------------------------
# """

# %%
# Ejecutamos varios modelos autorregresivo de orden n

# El segundo rezago no es significativo.

model_ar_2 = ARMA(df_ts['Córdoba'], order=(2,0))
results_ar_2 = model_ar_2.fit()

# %%
results_ar_2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                Córdoba   No. Observations:                 1093
# Model:                     ARMA(2, 0)   Log Likelihood               -6176.165
# Method:                       css-mle   S.D. of innovations             68.802
# Date:                Sun, 24 Jul 2022   AIC                          12360.329
# Time:                        23:17:04   BIC                          12380.316
# Sample:                             0   HQIC                         12367.893
#
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const           815.1850     12.303     66.258      0.000     791.071     839.299
# ar.L1.Córdoba     0.4687      0.028     16.629      0.000       0.413       0.524
# ar.L2.Córdoba     0.3632      0.028     12.878      0.000       0.308       0.418
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.1351           +0.0000j            1.1351            0.0000
# AR.2           -2.4256           +0.0000j            2.4256            0.5000
# -----------------------------------------------------------------------------
# """

# %%
# LLR Test para comparar 2 modelos

# testeamos dos modelos construyendo una funcion que nos devolvera un p valor. la hipotesis nula nos dice que los dos modelos son significativamente similares y la alternativa es que son diferentes

# DF son los grados de libertad, se sacan entre la diferencia entre los coeficientes del modelo 1 y 2.

def LLR_test(mod_1, mod_2, DF=1):
    # Buscamos las logsimilitudes de ambos modelos
    L1 = mod_1.llf
    L2 = mod_2.llf
    LR = (2*(L2-L1))
    p = chi2.sf(LR, DF).round(3)
    return p

# Comparamos modelos:
    
# Si son significativamente diferentes me voy a quedar con el mas simple de todos, el de menos rezagos

# Probamos el test para mas rezagos

model_ar_1 = ARMA(df_ts['Córdoba'], order=(1,0))
results_ar_1 = model_ar_1.fit()


model_ar_2 = ARMA(df_ts['Córdoba'], order=[2,0])
results_ar_2 = model_ar_2.fit()
#print(results_ar_4.summary()) 
print ("LLR test p-value = " + str(LLR_test(results_ar_1, results_ar_2)), 'AR-1 Vs AR-2')


model_ar_3 = ARMA(df_ts['Córdoba'], order=[3,0])
results_ar_3 = model_ar_3.fit()
#print(results_ar_4.summary()) 
print ("LLR test p-value = " + str(LLR_test(results_ar_2, results_ar_3)), 'AR-2 Vs AR-3')

model_ar_4 = ARMA(df_ts['Córdoba'], order=[4,0])
results_ar_4 = model_ar_4.fit()
#print(results_ar_4.summary()) 
print ("LLR test p-value = " + str(LLR_test(results_ar_3, results_ar_4)), 'AR-3 Vs AR-4')


model_ar_5 = ARMA(df_ts['Córdoba'], order=(5,0))
results_ar_5 = model_ar_5.fit()
#print(results_ar_5.summary())
print("LLR test p-value = " + str(LLR_test(results_ar_4, results_ar_5)), 'AR-4 Vs AR-5')

model_ar_6 = ARMA(df_ts['Córdoba'], order=(6,0))
results_ar_6 = model_ar_6.fit()
#print(results_ar_6.summary())
print("LLR test p-value = " + str(LLR_test(results_ar_5, results_ar_6)), 'AR-5 Vs AR-6')


model_ar_7 = ARMA(df_ts['Córdoba'], order=(7,0))
results_ar_7 = model_ar_7.fit()
#print(results_ar_7.summary())
print("LLR test p-value = " + str(LLR_test(results_ar_6, results_ar_7)), 'AR-6 Vs AR-7')


model_ar_8 = ARMA(df_ts['Córdoba'], order=(8,0))
results_ar_8 = model_ar_8.fit()
#print(results_ar_8.summary())
print("LLR test p-value = " + str(LLR_test(results_ar_7, results_ar_8)), 'AR-7 Vs AR-8')


# Nos quedamos con el modelo 5 ya que el sigueinte modelo no es significativo. incluir los precios de una semana atras nos puede dar buenos resultados. (dias habiles)
# Out:
# LLR test p-value = 0.0 AR-1 Vs AR-2
# LLR test p-value = 0.0 AR-2 Vs AR-3
# LLR test p-value = 0.001 AR-3 Vs AR-4
# LLR test p-value = 0.0 AR-4 Vs AR-5
# LLR test p-value = 0.457 AR-5 Vs AR-6
# LLR test p-value = 0.808 AR-6 Vs AR-7
# LLR test p-value = 0.318 AR-7 Vs AR-8

# %%
# Comparamos el AR1 y el AR5

# Aqui los grados de libertad seran 6. Los modelos no son similares, se rechaza la hipotesis nula y escogemos el modelo AR5 ya que añadir mas complejidad es significativamente mejor

print("LLR test: " + str(LLR_test(results_ar_1, results_ar_5, DF = 4)))
# Out:
# LLR test: 0.0

# %% [markdown]
# Analizamos los residuos del modelo 5
# tienen que ser ruido blanco, no deben tener autocorrelacion y deben ser estacionarios

# %%
df_ts['res_price'] = results_ar_5.resid
sts.adfuller(df_ts.res_price)[1]
# Out:
# 0.0

# %% [markdown]
# autocorrelacion: la mayoria cae en area azul, no hay autocorrelacion

# %%
sgt.plot_acf(df_ts.res_price, zero = False, lags = 40)
plt.title("ACF Of Residuals for Prices",size=24)
plt.show()

# %%
df_ts.res_price[1:].plot(figsize=(20,5))
plt.title("Residuals of Prices",size=24)
plt.show()

# %%
# pct_change es un metodo de pandas, porcentaje de cambio entre el periodo actual y el anterior, ponemos 1 porque queremos un periodo. Si queremos los porcentajes ponemos mul 100

#df_ts['returns'] = df_ts['Córdoba'].pct_change(1).mul(100)

# Eliminamos la primer fila ya que al poner los retornos nos quedamos sin un valor

#df  = df.iloc[1:]

#df['returns'].plot(figsize=(12,8));

# %%
# Aplicamos test de Dickey Fuller para los retornos y vemos que es estacionaria

'''
if sts.adfuller(df_ts.returns)[0] > sts.adfuller(df_ts.returns)[4]['1%']:
    print('No rechazamos hipotesis nula, la serie NO ES estacionaria a un nivel de significacion del 1 % con un numero de retrasos de: ', sts.adfuller(df.returns)[2])

elif sts.adfuller(df_ts.returns)[0] > sts.adfuller(df_ts.returns)[4]['5%']:
    print('No rechazamos hipotesis nula, la serie NO ES estacionaria a un nivel de significacion del 5 % con un numero de retrasos de: ', sts.adfuller(df.returns)[2])
    
elif sts.adfuller(df_ts.returns)[0] > sts.adfuller(df_ts.returns)[4]['10%']:
    print('No rechazamos hipotesis nula, la serie NO ES estacionaria a un nivel de significacion del 10 % con un numero de retrasos de: ', sts.adfuller(df.returns)[2])

else: print('La serie ES estacionaria')'''
# Out:
# "\nif sts.adfuller(df_ts.returns)[0] > sts.adfuller(df_ts.returns)[4]['1%']:\n    print('No rechazamos hipotesis nula, la serie NO ES estacionaria a un nivel de significacion del 1 % con un numero de retrasos de: ', sts.adfuller(df.returns)[2])\n\nelif sts.adfuller(df_ts.returns)[0] > sts.adfuller(df_ts.returns)[4]['5%']:\n    print('No rechazamos hipotesis nula, la serie NO ES estacionaria a un nivel de significacion del 5 % con un numero de retrasos de: ', sts.adfuller(df.returns)[2])\n    \nelif sts.adfuller(df_ts.returns)[0] > sts.adfuller(df_ts.returns)[4]['10%']:\n    print('No rechazamos hipotesis nula, la serie NO ES estacionaria a un nivel de significacion del 10 % con un numero de retrasos de: ', sts.adfuller(df.returns)[2])\n\nelse: print('La serie ES estacionaria')"

# %%
df_ts
# Out:
#             Córdoba  6-month-sma  12-month-sma   res_price
# date
# 2018-01-02    877.0          NaN           NaN   61.107614
# 2018-01-03    737.0          NaN           NaN -123.793113
# 2018-01-04    760.0          NaN           NaN  -41.107624
# 2018-01-05    838.0          NaN           NaN   53.617090
# 2018-01-08    803.0          NaN           NaN   -1.629588
# ...             ...          ...           ...         ...
# 2022-06-23    781.0   826.000000    815.416667  -54.731933
# 2022-06-24    846.0   833.166667    823.000000   32.914732
# 2022-06-28    920.0   853.166667    835.333333   88.666077
# 2022-06-29    920.0   858.500000    842.666667   58.252357
# 2022-06-30    916.0   868.166667    851.000000   35.807019
#
# [1093 rows x 4 columns]

# %%
train = df_ts.iloc[:df_ts.shape[0] - 365]

test = df_ts.iloc[df_ts.shape[0] - 365:]

start = len(train)

end = len(train) + len(test) - 20

model_ar_5 = ARMA(train['Córdoba'], order=(5,0))
results_ar_5 = model_ar_5.fit(maxlag = 5, method = 'mle')

predictions = results_ar_5.predict(start = start,
                                   end = end,
                                   dynamic = False).rename('predictions')

# %%
pred = pd.DataFrame(data={'predictions': predictions.values[:-1]}, index = df_ts.iloc[start:end].index)

# %%
fig, ax = plt.subplots(figsize=(14, 6))
train['Córdoba'].plot(ax=ax, label='train')
test['Córdoba'].plot(ax=ax, label='test')
pred.plot(ax=ax, label='predictions')
ax.legend();
